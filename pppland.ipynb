# %%
# -*- coding: utf-8 -*-
import sys
# import alsaaudio
import serial

# Create object serial port
portName = "COM5"                      # replace this port name by yours!
baudrate = 115200
ser = serial.Serial(portName,baudrate)

from scipy import arange, fft, fromstring, roll, zeros
import numpy as np

import pyqtgraph as pg
from pyqtgraph.Qt import QtGui, QtCore

fftLen = 2048
shift = 4
signal_scale = 1. / 2000

capture_setting = {
    "ch" : 1,
    "fs" : 16000,
    "chunk" : shift
    }

ppp = np.zeros(0)

def spectrumAnalyzer():
    global fftLen, capture_setting, signal_scale
    # ========================
    #  Capture Sound from Mic
    # ========================
    ch = capture_setting["ch"]
    fs = capture_setting["fs"]
    chunk = capture_setting["chunk"]
#     inPCM = alsaaudio.PCM(alsaaudio.PCM_CAPTURE)
#     inPCM.setchannels(ch)
#     inPCM.setrate(fs)
#     inPCM.setformat(alsaaudio.PCM_FORMAT_S16_LE)
#     inPCM.setperiodsize(chunk)
    ### FFT する信号
    signal = zeros(fftLen, dtype = float)

    # ========
    #  Layout
    # ========

    ### アプリケーション作成
    app = QtGui.QApplication([])
    app.quitOnLastWindowClosed()
    ### メインウィンドウ
    mainWindow = QtGui.QMainWindow()
    mainWindow.setWindowTitle("Spectrum Analyzer") # Title
    mainWindow.resize(800, 300) # Size
    ### キャンパス
    centralWid = QtGui.QWidget()
    mainWindow.setCentralWidget(centralWid)
    ### レイアウト！！
    lay = QtGui.QVBoxLayout()
    centralWid.setLayout(lay)
    
    ### スペクトル表示用ウィジット
    specWid = pg.PlotWidget(name="spectrum")
    specItem = specWid.getPlotItem()
    specItem.setMouseEnabled(y = False) # y軸方向に動かせなくする
    specItem.setYRange(0, 1000)
    specItem.setXRange(0, fftLen / 2, padding = 0)
    ### Axis
    specAxis = specItem.getAxis("bottom")
    specAxis.setLabel("Frequency [Hz]")
    specAxis.setScale(fs / 2. / (fftLen / 2 + 1))
    hz_interval = 500
    newXAxis = (arange(int(fs / 2 / hz_interval)) + 1) * hz_interval
    oriXAxis = newXAxis / (fs / 2. / (fftLen / 2 + 1))
    specAxis.setTicks([zip(oriXAxis, newXAxis)])
    ### キャンパスにのせる
    lay.addWidget(specWid)
    
    ### ウィンドウ表示
    mainWindow.show()
        
    ### Update
    while 1:
        data = ser.readline()
        length = ser.readline()
        print(data)
        dd = data.decode()
        op = int(dd)
        print(op)
        print(type(op))
        pp= np.append(ppp,op)
        
        num_data = fromstring(pp,dtype = "int16")
        signal = roll(signal, - chunk)
        signal[- chunk :] = num_data
        fftspec = fft(signal)
        specItem.plot(abs(fftspec[1 : fftLen // 2 + 1] * signal_scale), clear = True)
        QtGui.QApplication.processEvents()
        

if __name__ == "__main__":
    spectrumAnalyzer()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
# b'911\r\n'
# 911
# <class 'int'>
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: DeprecationWarning: scipy.fromstring is deprecated and will be removed in SciPy 2.0.0, use numpy.fromstring instead
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:95: DeprecationWarning: scipy.roll is deprecated and will be removed in SciPy 2.0.0, use numpy.roll instead
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: DeprecationWarning: Using scipy.fft as a function is deprecated and will be removed in SciPy 1.5.0, use scipy.fft.fft instead.
# b'1015\r\n'
# 1015
# <class 'int'>
# b'963\r\n'
# 963
# <class 'int'>
# b'1080\r\n'
# 1080
# <class 'int'>
# b'1027\r\n'
# 1027
# <class 'int'>
# b'1075\r\n'
# 1075
# <class 'int'>
# b'1064\r\n'
# 1064
# <class 'int'>
# b'936\r\n'
# 936
# <class 'int'>
# b'941\r\n'
# 941
# <class 'int'>
# b'1011\r\n'
# 1011
# <class 'int'>
# b'933\r\n'
# 933
# <class 'int'>
# b'1074\r\n'
# 1074
# <class 'int'>
# b'1055\r\n'
# 1055
# <class 'int'>
# b'978\r\n'
# 978
# <class 'int'>
# b'1110\r\n'
# 1110
# <class 'int'>
# b'968\r\n'
# 968
# <class 'int'>
# b'1046\r\n'
# 1046
# <class 'int'>
# b'1004\r\n'
# 1004
# <class 'int'>
# b'992\r\n'
# 992
# <class 'int'>
# b'1086\r\n'
# 1086
# <class 'int'>
# b'987\r\n'
# 987
# <class 'int'>
# b'1105\r\n'
# 1105
# <class 'int'>
# b'1081\r\n'
# 1081
# <class 'int'>
# b'1097\r\n'
# 1097
# <class 'int'>
# b'1088\r\n'
# 1088
# <class 'int'>
# b'1002\r\n'
# 1002
# <class 'int'>
# b'1049\r\n'
# 1049
# <class 'int'>
# b'1057\r\n'
# 1057
# <class 'int'>
# b'1263\r\n'
# 1263
# <class 'int'>
# b'952\r\n'
# 952
# <class 'int'>
# b'919\r\n'
# 919
# <class 'int'>
# b'962\r\n'
# 962
# <class 'int'>
# b'883\r\n'
# 883
# <class 'int'>
# b'1036\r\n'
# 1036
# <class 'int'>
# b'969\r\n'
# 969
# <class 'int'>
# b'994\r\n'
# 994
# <class 'int'>
# b'1017\r\n'
# 1017
# <class 'int'>
# b'1042\r\n'
# 1042
# <class 'int'>
# b'997\r\n'
# 997
# <class 'int'>
# b'967\r\n'
# 967
# <class 'int'>
# b'899\r\n'
# 899
# <class 'int'>
# b'742\r\n'
# 742
# <class 'int'>
# b'643\r\n'
# 643
# <class 'int'>
# b'920\r\n'
# 920
# <class 'int'>
# b'922\r\n'
# 922
# <class 'int'>
# b'867\r\n'
# 867
# <class 'int'>
# b'866\r\n'
# 866
# <class 'int'>
# b'819\r\n'
# 819
# <class 'int'>
# b'849\r\n'
# 849
# <class 'int'>
# b'818\r\n'
# 818
# <class 'int'>
# b'830\r\n'
# 830
# <class 'int'>
# b'832\r\n'
# 832
# <class 'int'>
# b'868\r\n'
# 868
# <class 'int'>
# b'892\r\n'
# 892
# <class 'int'>
# b'852\r\n'
# 852
# <class 'int'>
# b'877\r\n'
# 877
# <class 'int'>
# b'855\r\n'
# 855
# <class 'int'>
# b'890\r\n'
# 890
# <class 'int'>
# b'945\r\n'
# 945
# <class 'int'>
# b'979\r\n'
# 979
# <class 'int'>
# b'1037\r\n'
# 1037
# <class 'int'>
# b'1015\r\n'
# 1015
# <class 'int'>
# b'1108\r\n'
# 1108
# <class 'int'>
# b'1061\r\n'
# 1061
# <class 'int'>
# b'936\r\n'
# 936
# <class 'int'>
# b'921\r\n'
# 921
# <class 'int'>
# b'873\r\n'
# 873
# <class 'int'>
# b'909\r\n'
# 909
# <class 'int'>
# b'938\r\n'
# 938
# <class 'int'>
# b'915\r\n'
# 915
# <class 'int'>
# b'983\r\n'
# 983
# <class 'int'>
# b'921\r\n'
# 921
# <class 'int'>
# b'997\r\n'
# 997
# <class 'int'>
# b'1004\r\n'
# 1004
# <class 'int'>
# b'960\r\n'
# 960
# <class 'int'>
# b'1324\r\n'
# 1324
# <class 'int'>
# b'998\r\n'
# 998
# <class 'int'>
# b'1042\r\n'
# 1042
# <class 'int'>
# b'987\r\n'
# 987
# <class 'int'>
# b'884\r\n'
# 884
# <class 'int'>
# b'918\r\n'
# 918
# <class 'int'>
# b'986\r\n'
# 986
# <class 'int'>
# b'1089\r\n'
# 1089
# <class 'int'>
# b'997\r\n'
# 997
# <class 'int'>
# b'965\r\n'
# 965
# <class 'int'>
# b'1020\r\n'
# 1020
# <class 'int'>
# b'990\r\n'
# 990
# <class 'int'>
# b'920\r\n'
# 920
# <class 'int'>
# b'1019\r\n'
# 1019
# <class 'int'>
# b'1040\r\n'
# 1040
# <class 'int'>
# b'988\r\n'
# 988
# <class 'int'>
# b'1077\r\n'
# 1077
# <class 'int'>
# b'989\r\n'
# 989
# <class 'int'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c41ec29ae6c3> in <module>
#     101
#     102 if __name__ == "__main__":
# --> 103     spectrumAnalyzer()
#
# <ipython-input-1-c41ec29ae6c3> in spectrumAnalyzer()
#      84     while 1:
#      85         data = ser.readline()
# ---> 86         length = ser.readline()
#      87         print(data)
#      88         dd = data.decode()
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialwin32.py in read(self, size)
#     288                     ctypes.byref(self._overlapped_read),
#     289                     ctypes.byref(rc),
# --> 290                     True)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:
